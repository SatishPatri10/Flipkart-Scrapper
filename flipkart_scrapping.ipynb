# %% [markdown]
# __Import Library__

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask_cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %% [markdown]
# __Search Query__

# %%
search_string = "Realme5s"

# %%
flipkart_url = "https://www.flipkart.com/search?q="+ search_string
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=Realme5s'

# %%
uclient = uReq(flipkart_url)

# %%
uclient

# %%
flipkartpage = uclient.read()

# %%
flipkart_html = bs(flipkartpage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
len(bigboxes)
# Out:
# 19

# %%
box = bigboxes[2]

# %% [markdown]
# __Reachout to particular product page__

# %%
product_link = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
prod_req = requests.get(product_link)
prod_req
# Out:
# <Response [200]>

# %%
prod_html = bs(prod_req.text, "html.parser")

# %%
all_review = prod_html.find_all('div',{"class":"_16PBlm"})

# %%
comment_box = prod_html.find_all("div" , {"class" : "_16PBlm" })

# %%
comment_box[1].div.div.find_all("div" , {"class" : ""})
# Out:
# [<div><div class="">Best Phone in this range...... Best camera best Battery superb phone.... Suggest you to buy</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Best Phone in this range...... Best camera best Battery superb phone.... Suggest you to buy</div>,
#  <div></div>]

# %%
for i in comment_box :
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 4
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [20], line 2
#       1 for i in comment_box :
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[1].div.div.find_all("div" ,{"class" : ""})
# Out:
# [<div><div class="">Best Phone in this range...... Best camera best Battery superb phone.... Suggest you to buy</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Best Phone in this range...... Best camera best Battery superb phone.... Suggest you to buy</div>,
#  <div></div>]

# %%
for i in comment_box : 
    print(i.div.div.find_all("div" ,{"class" : ""})[0].div.text)
    print("\n")
# Out:
# If you are looking for a phone for your mom or dad this is perfectPros1) The camera is very good in normal mode, Ultra 48, selfie, slowmo and video recording 2) The processor is very good for browsing, social media, YouTube, Netflix and stuff like that 3) People say that the display is bad but the brightness of the display is good and okay for your parents or mild user for what I mentioned above but the brightness is definitely on the dimmer side when you step out in the sun 4) The batt...
#
#
# Best Phone in this range...... Best camera best Battery superb phone.... Suggest you to buy
#
#
# good battery and display I am very happy real me love you thanks for Flipkart amazing product only on
#
#
# Realme 5s good mobile value for money good camera good performance i really loving it
#
#
# ...

# %%
comment_box[1].div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })
# Out:
# [<p class="_2sc7ZR _2V5EHH">Afzal Taz</p>]

# %%
for i in comment_box:
    print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0])
# Out:
# <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>
# <p class="_2sc7ZR _2V5EHH">Afzal Taz</p>
# <p class="_2sc7ZR _2V5EHH">Santosh Kumar</p>
# <p class="_2sc7ZR _2V5EHH">Robin.V</p>
# <p class="_2sc7ZR _2V5EHH">Abhishek Das</p>
# <p class="_2sc7ZR _2V5EHH">Meman Adil</p>
# <p class="_2sc7ZR _2V5EHH">Prabhu Chan</p>
# <p class="_2sc7ZR _2V5EHH">Jagdeep Sharma </p>
# <p class="_2sc7ZR _2V5EHH">Subhankar Pal</p>
# <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [28], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0])
#
# AttributeError: 'NoneType' object has no attribute 'div'
